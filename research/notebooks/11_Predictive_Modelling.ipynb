# %% [markdown]
# # Predictive Modelling
# Build a churn prediction model that **maximizes identification of churn-risk customers**, supports **risk segmentation**, and enables **targeted retention actions**, rather than blindly maximizing accuracy.

# %% [markdown]
# ### Churn Definition
#
# * **Churn = customer leaves the company**
#
# * Business cost of:
#
#   * False Negative (FN) → Customer will actually churn but model predict no churn (HIGH COST)
#
#   * False Positive (FP) → Customer will not churn but model predict churn - To keep those customers company offers unnecessary discount (LOWER COST)
#
#
# **Therefore:**
# Recall for churners matters more than accuracy.

# %%
## Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

from sklearn.model_selection import GridSearchCV

from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import RandomOverSampler, SMOTE

# %%
## Load cleaned and transformed dataset (after feature engineering)
X_train = pd.read_csv("..\\data\\processed\\X_train.csv")
X_test = pd.read_csv("..\\data\\processed\\X_test.csv")
y_train = pd.read_csv("..\\data\\processed\\y_train.csv")
y_test = pd.read_csv("..\\data\\processed\\y_test.csv")

print("X_train Shape: ", X_train.shape)
print("X_test Shape: ", X_test.shape)
print("y_train Shape: ", y_train.shape)
print("y_test Shape: ", y_test.shape)
# Out:
# X_train Shape:  (5616, 23)
# X_test Shape:  (1405, 23)
# y_train Shape:  (5616, 1)
# y_test Shape:  (1405, 1)

# %%
X_train.head()
# Out:
#    gender  SeniorCitizen  Partner  Dependents    tenure  PhoneService  \
# 0     1.0              0        0           0  0.321940             1
# 1     1.0              1        1           0 -0.208976             1
# 2     1.0              0        0           0 -0.045617             1
# 3     0.0              0        1           1 -0.739893             1
# 4     1.0              0        0           0 -1.025771             1
#
#    MultipleLines  OnlineSecurity  OnlineBackup  DeviceProtection  ...  \
# 0              1               0             0                 0  ...
# 1              1               1             0                 1  ...
# 2              0               0             0                 0  ...
# 3              0               1             1                 0  ...
# 4              1               0             0                 0  ...
#
#    PaperlessBilling  MonthlyCharges  TotalCharges  \
# 0                 1        0.674759      0.495749
# ...

# %%
print(y_train.ndim)
y_train.head()
# Out:
# 2
#    Churn
# 0      0
# 1      0
# 2      0
# 3      0
# 4      1

# %%
y_train = y_train['Churn']
y_train.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    1
# Name: Churn, dtype: int64

# %%
y_test = y_test['Churn']
y_test.shape
# Out:
# (1405,)

# %% [markdown]
# ## Build Model

# %%
## Logistic Regression Model
log_reg_model = LogisticRegression(class_weight='balanced')

# Train the model
log_reg_model.fit(X_train, y_train)
# Out:
# LogisticRegression(class_weight='balanced')

# %% [markdown]
# ### Evaluate

# %%
## Prediction on training data
y_train_pred = log_reg_model.predict(X_train)

## Calculate accuracy
training_score = classification_report(y_train, y_train_pred)

# %%
## Prediction on testing data
y_test_pred = log_reg_model.predict(X_test)

## Calculate accuracy
test_score = classification_report(y_test, y_test_pred)

print("\n\nTraining Score\n", training_score, "\n\n\nTesting Score\n", test_score)
# Out:
# Training Score
#                precision    recall  f1-score   support
#
#            0       0.91      0.73      0.81      4122
#            1       0.52      0.80      0.63      1494
#
#     accuracy                           0.75      5616
#    macro avg       0.72      0.77      0.72      5616
# weighted avg       0.81      0.75      0.76      5616
#
#
#
# Testing Score
#                precision    recall  f1-score   support
#
#            0       0.91      0.74      0.82      1033
#            1       0.53      0.81      0.64       372
#
#     accuracy                           0.76      1405
#    macro avg       0.72      0.77      0.73      1405
# weighted avg       0.81      0.76      0.77      1405

# %% [markdown]
# #### Comment:
# It shows training and testing accuracy is 75% and 76%  and recall is 77% which is not bad but let's try to improve recall with another non-linear model.

# %% [markdown]
# ## Build model with Random Forest

# %%
## Train the model
rf_model = RandomForestClassifier(random_state=42, class_weight='balanced')
rf_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', random_state=42)

# %%
## Predict with model
y_train_pred = rf_model.predict(X_train)
y_test_pred = rf_model.predict(X_test)

# %%
## Evaluate
training_score = classification_report(y_train, y_train_pred)
test_score = classification_report(y_test, y_test_pred)

print("\n\nTraining Score\n", training_score, "\n\n\nTesting Score\n", test_score)
# Out:
# Training Score
#                precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00      4122
#            1       0.98      1.00      0.99      1494
#
#     accuracy                           0.99      5616
#    macro avg       0.99      1.00      0.99      5616
# weighted avg       0.99      0.99      0.99      5616
#
#
#
# Testing Score
#                precision    recall  f1-score   support
#
#            0       0.87      0.84      0.85      1033
#            1       0.59      0.65      0.61       372
#
#     accuracy                           0.79      1405
#    macro avg       0.73      0.74      0.73      1405
# weighted avg       0.79      0.79      0.79      1405

# %% [markdown]
# #### Comment:
# It shows overfitting (training accuracy is high and test accuracy is low)

# %% [markdown]
# ### Hyperparameter Tuning

# %%
## Train the model
rf_model = RandomForestClassifier(
    n_estimators = 200,
    max_depth = 10,
    class_weight='balanced',
    random_state=42)
rf_model.fit(X_train, y_train)

## Predict with model
y_train_pred = rf_model.predict(X_train)
y_test_pred = rf_model.predict(X_test)


## Evaluate
training_score = classification_report(y_train, y_train_pred)
test_score = classification_report(y_test, y_test_pred)

print("\n\nTraining Score\n", training_score, "\n\n\nTesting Score\n", test_score)
# Out:
# Training Score
#                precision    recall  f1-score   support
#
#            0       0.98      0.82      0.90      4122
#            1       0.66      0.95      0.78      1494
#
#     accuracy                           0.86      5616
#    macro avg       0.82      0.89      0.84      5616
# weighted avg       0.90      0.86      0.87      5616
#
#
#
# Testing Score
#                precision    recall  f1-score   support
#
#            0       0.90      0.78      0.83      1033
#            1       0.55      0.75      0.64       372
#
#     accuracy                           0.77      1405
#    macro avg       0.72      0.77      0.74      1405
# weighted avg       0.81      0.77      0.78      1405

# %%
## Train the model
rf_model = RandomForestClassifier(
    n_estimators = 200,
    max_depth = 15,
    class_weight='balanced',
    random_state=42)
rf_model.fit(X_train, y_train)

## Predict with model
y_train_pred = rf_model.predict(X_train)
y_test_pred = rf_model.predict(X_test)

## Evaluate
training_score = classification_report(y_train, y_train_pred)
test_score = classification_report(y_test, y_test_pred)

print("\n\nTraining Score\n", training_score, "\n\n\nTesting Score\n", test_score)
# Out:
# Training Score
#                precision    recall  f1-score   support
#
#            0       1.00      0.94      0.97      4122
#            1       0.85      1.00      0.92      1494
#
#     accuracy                           0.95      5616
#    macro avg       0.93      0.97      0.94      5616
# weighted avg       0.96      0.95      0.96      5616
#
#
#
# Testing Score
#                precision    recall  f1-score   support
#
#            0       0.88      0.82      0.85      1033
#            1       0.58      0.68      0.62       372
#
#     accuracy                           0.78      1405
#    macro avg       0.73      0.75      0.74      1405
# weighted avg       0.80      0.78      0.79      1405

# %% [markdown]
# ### Grid Search CV

# %%
param_grid = {
    'n_estimators': [200,300, 400],
    'max_depth': [10,15],
    'min_samples_leaf': [12,15,18],
    'max_features': ['log2'],
    'class_weight':['balanced'],
}

clf_grid = GridSearchCV(
    estimator = RandomForestClassifier(random_state=42),
    param_grid = param_grid,
    cv=5,
    scoring='recall',
    n_jobs=-1
)

## Fit
clf_grid.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(random_state=42), n_jobs=-1,
#              param_grid={'class_weight': ['balanced'], 'max_depth': [10, 15],
#                          'max_features': ['log2'],
#                          'min_samples_leaf': [12, 15, 18],
#                          'n_estimators': [200, 300, 400]},
#              scoring='recall')

# %%
## Get the best model
best_clf = clf_grid.best_estimator_

## Predict with model
y_train_pred = best_clf.predict(X_train)
y_test_pred = best_clf.predict(X_test)

## Evaluate
training_score = classification_report(y_train, y_train_pred)
test_score = classification_report(y_test, y_test_pred)

print("\n\nTraining Score\n", training_score, "\n\n\nTesting Score\n", test_score)
# Out:
# Training Score
#                precision    recall  f1-score   support
#
#            0       0.93      0.77      0.85      4122
#            1       0.57      0.84      0.68      1494
#
#     accuracy                           0.79      5616
#    macro avg       0.75      0.81      0.76      5616
# weighted avg       0.84      0.79      0.80      5616
#
#
#
# Testing Score
#                precision    recall  f1-score   support
#
#            0       0.91      0.76      0.83      1033
#            1       0.55      0.79      0.65       372
#
#     accuracy                           0.77      1405
#    macro avg       0.73      0.78      0.74      1405
# weighted avg       0.81      0.77      0.78      1405

# %% [markdown]
# #### Comment:
# Here recall is not so bad but let's try some feature enginnering.

# %%
## Find out best features
rf = RandomForestClassifier(random_state=42, n_estimators=100)
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
feature_importance = (
    pd.DataFrame({
        'Feature': X_train.columns,
        'Importance': rf.feature_importances_
    })
    .sort_values(by='Importance', ascending=False)
)

feature_importance.head(20)
# Out:
#                            Feature  Importance
# 15                    TotalCharges    0.193965
# 14                  MonthlyCharges    0.180483
# 4                           tenure    0.174190
# 16     InternetService_Fiber optic    0.047036
# 21  PaymentMethod_Electronic check    0.037541
# 0                           gender    0.028586
# 13                PaperlessBilling    0.028303
# 19               Contract_Two year    0.028067
# 7                   OnlineSecurity    0.024739
# 10                     TechSupport    0.024056
# 2                          Partner    0.022712
# 8                     OnlineBackup    0.022000
# 18               Contract_One year    0.020817
# 1                    SeniorCitizen    0.020622
# 6                    MultipleLines    0.020575
# 3                       Dependents    0.019579
# 9                 DeviceProtection    0.019307
# 12                 StreamingMovies    0.018862
# 11                     StreamingTV    0.017814
# ...

# %%
## Select top features which has importance greater than 0.02
important_features = feature_importance[feature_importance['Importance']>0.02]['Feature'].values
important_features
# Out:
# <StringArray>
# [                  'TotalCharges',                 'MonthlyCharges',
#                          'tenure',    'InternetService_Fiber optic',
#  'PaymentMethod_Electronic check',                         'gender',
#                'PaperlessBilling',              'Contract_Two year',
#                  'OnlineSecurity',                    'TechSupport',
#                         'Partner',                   'OnlineBackup',
#               'Contract_One year',                  'SeniorCitizen',
#                   'MultipleLines']
# Length: 15, dtype: str

# %%
## Final features with important features
X_train_final = X_train[important_features]
X_test_final = X_test[important_features]

print(X_train_final.shape, X_test_final.shape)
# Out:
# (5616, 15) (1405, 15)

# %%
## Grid Search with final data
param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [8, 10,12],
    'min_samples_leaf': [8,10,12],
    'class_weight':['balanced']
}

clf_grid = GridSearchCV(
    estimator = RandomForestClassifier(random_state=42),
    param_grid = param_grid,
    cv=5,
    scoring='recall',
    n_jobs=-1
)

## Fit
clf_grid.fit(X_train_final, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(random_state=42), n_jobs=-1,
#              param_grid={'class_weight': ['balanced'], 'max_depth': [8, 10, 12],
#                          'min_samples_leaf': [8, 10, 12],
#                          'n_estimators': [100, 200, 300]},
#              scoring='recall')

# %%
## Get the best model
best_clf = clf_grid.best_estimator_

## Predict with model
y_train_pred = best_clf.predict(X_train_final)
y_test_pred = best_clf.predict(X_test_final)

## Evaluate
training_score = classification_report(y_train, y_train_pred)
test_score = classification_report(y_test, y_test_pred)

print("\n\nTraining Score\n", training_score, "\n\n\nTesting Score\n", test_score)
# Out:
# Training Score
#                precision    recall  f1-score   support
#
#            0       0.92      0.77      0.84      4122
#            1       0.57      0.83      0.67      1494
#
#     accuracy                           0.79      5616
#    macro avg       0.75      0.80      0.76      5616
# weighted avg       0.83      0.79      0.80      5616
#
#
#
# Testing Score
#                precision    recall  f1-score   support
#
#            0       0.90      0.76      0.82      1033
#            1       0.53      0.77      0.63       372
#
#     accuracy                           0.76      1405
#    macro avg       0.72      0.76      0.73      1405
# weighted avg       0.80      0.76      0.77      1405

# %% [markdown]
# #### Comment:
# Here accuracy has improved a little bit but not recall. It's probably for imbalance data. Let's try to balance the dataset.

# %% [markdown]
# ## Handle Imbalance Data

# %%
y_train.value_counts(normalize=True)
# Out:
# Churn
# 0    0.733974
# 1    0.266026
# Name: proportion, dtype: float64

# %%
((y_train.value_counts(normalize=True)*100).round(2)).plot(kind='bar', color=['orange', 'green'])
plt.title("Classes percentage in target")
plt.ylabel("Percentage")
# Out:
# Text(0, 0.5, 'Percentage')

# %% [markdown]
# #### Comment:
# It is clear that the data is imbalance. We should fix it.

# %% [markdown]
# ### Under Sampling

# %%
## Resample 
rus = RandomUnderSampler(random_state=0)
X_train_resampled, y_train_resampled = rus.fit_resample(X_train, y_train)

print(X_train_resampled.shape, y_train_resampled.shape)
# Out:
# (2988, 23) (2988,)

# %%
## Model training and evaluation
rfc = RandomForestClassifier(n_estimators=100, random_state=42)
rfc.fit(X_train_resampled, y_train_resampled)

## Predict with model
y_train_pred = rfc.predict(X_train_resampled)
y_test_pred = rfc.predict(X_test)

## Evaluate
training_score = classification_report(y_train_resampled, y_train_pred)
test_score = classification_report(y_test, y_test_pred)

print("\n\nTraining Score\n", training_score, "\n\n\nTesting Score\n", test_score)
# Out:
# Training Score
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1494
#            1       1.00      1.00      1.00      1494
#
#     accuracy                           1.00      2988
#    macro avg       1.00      1.00      1.00      2988
# weighted avg       1.00      1.00      1.00      2988
#
#
#
# Testing Score
#                precision    recall  f1-score   support
#
#            0       0.90      0.75      0.82      1033
#            1       0.53      0.76      0.62       372
#
#     accuracy                           0.76      1405
#    macro avg       0.71      0.76      0.72      1405
# weighted avg       0.80      0.76      0.77      1405

# %%
## Model training and evaluation
rfc = RandomForestClassifier(max_depth=10, min_samples_leaf=15, n_estimators=200, random_state=42)
rfc.fit(X_train_resampled, y_train_resampled)

## Predict with model
y_train_pred = rfc.predict(X_train_resampled)
y_test_pred = rfc.predict(X_test)

## Evaluate
training_score = classification_report(y_train_resampled, y_train_pred)
test_score = classification_report(y_test, y_test_pred)

print("\n\nTraining Score\n", training_score, "\n\n\nTesting Score\n", test_score)
# Out:
# Training Score
#                precision    recall  f1-score   support
#
#            0       0.81      0.77      0.79      1494
#            1       0.78      0.82      0.80      1494
#
#     accuracy                           0.79      2988
#    macro avg       0.79      0.79      0.79      2988
# weighted avg       0.79      0.79      0.79      2988
#
#
#
# Testing Score
#                precision    recall  f1-score   support
#
#            0       0.91      0.76      0.83      1033
#            1       0.55      0.80      0.65       372
#
#     accuracy                           0.77      1405
#    macro avg       0.73      0.78      0.74      1405
# weighted avg       0.82      0.77      0.78      1405

# %% [markdown]
# ### Over Sampling

# %%
## Resample 
ros = RandomOverSampler(random_state=0)
X_train_resampled, y_train_resampled = ros.fit_resample(X_train, y_train)

print(X_train_resampled.shape, y_train_resampled.shape)
# Out:
# (8244, 23) (8244,)

# %%
## Model training and evaluation
rfc = RandomForestClassifier(max_depth=10, min_samples_leaf=15, n_estimators=200, random_state=42)
rfc.fit(X_train_resampled, y_train_resampled)

## Predict with model
y_train_pred = rfc.predict(X_train_resampled)
y_test_pred = rfc.predict(X_test)

## Evaluate
training_score = classification_report(y_train_resampled, y_train_pred)
test_score = classification_report(y_test, y_test_pred)

print("\n\nTraining Score\n", training_score, "\n\n\nTesting Score\n", test_score)
# Out:
# Training Score
#                precision    recall  f1-score   support
#
#            0       0.84      0.79      0.81      4122
#            1       0.80      0.85      0.83      4122
#
#     accuracy                           0.82      8244
#    macro avg       0.82      0.82      0.82      8244
# weighted avg       0.82      0.82      0.82      8244
#
#
#
# Testing Score
#                precision    recall  f1-score   support
#
#            0       0.90      0.77      0.83      1033
#            1       0.55      0.76      0.64       372
#
#     accuracy                           0.77      1405
#    macro avg       0.72      0.77      0.73      1405
# weighted avg       0.81      0.77      0.78      1405

# %% [markdown]
# ### SMOTE

# %%
## Resample 
smote = SMOTE(random_state=0)
X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)

print(X_train_resampled.shape, y_train_resampled.shape)
# Out:
# (8244, 23) (8244,)

# %%
## Model training and evaluation
rfc = RandomForestClassifier(max_depth=10, min_samples_leaf=15, n_estimators=200, random_state=42)
rfc.fit(X_train_resampled, y_train_resampled)

## Predict with model
y_train_pred = rfc.predict(X_train_resampled)
y_test_pred = rfc.predict(X_test)

## Evaluate
training_score = classification_report(y_train_resampled, y_train_pred)
test_score = classification_report(y_test, y_test_pred)

print("\n\nTraining Score\n", training_score, "\n\n\nTesting Score\n", test_score)
# Out:
# Training Score
#                precision    recall  f1-score   support
#
#            0       0.85      0.80      0.82      4122
#            1       0.81      0.86      0.84      4122
#
#     accuracy                           0.83      8244
#    macro avg       0.83      0.83      0.83      8244
# weighted avg       0.83      0.83      0.83      8244
#
#
#
# Testing Score
#                precision    recall  f1-score   support
#
#            0       0.90      0.78      0.84      1033
#            1       0.56      0.75      0.64       372
#
#     accuracy                           0.78      1405
#    macro avg       0.73      0.77      0.74      1405
# weighted avg       0.81      0.78      0.78      1405

# %%
X_train.shape
# Out:
# (5616, 23)

# %%
param_grid = {
    'n_estimators': [200,300,400],
    'max_depth': [8, 10,15],
    'min_samples_leaf': [15,18],
    'max_features': ['log2']
}

clf_grid = GridSearchCV(
    estimator = RandomForestClassifier(random_state=42),
    param_grid = param_grid,
    scoring='recall',
    cv=5,
    n_jobs=-1
)

## Fit
clf_grid.fit(X_train_resampled, y_train_resampled)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(random_state=42), n_jobs=-1,
#              param_grid={'max_depth': [8, 10, 15], 'max_features': ['log2'],
#                          'min_samples_leaf': [15, 18],
#                          'n_estimators': [200, 300, 400]},
#              scoring='recall')

# %%
## Get the best model
best_clf = clf_grid.best_estimator_

## Predict with model
y_train_pred = best_clf.predict(X_train_resampled)
y_test_pred = best_clf.predict(X_test)

## Evaluate
training_score = classification_report(y_train_resampled, y_train_pred)
test_score = classification_report(y_test, y_test_pred)

print("\n\nTraining Score\n", training_score, "\n\n\nTesting Score\n", test_score)
# Out:
# Training Score
#                precision    recall  f1-score   support
#
#            0       0.85      0.78      0.81      4122
#            1       0.80      0.86      0.83      4122
#
#     accuracy                           0.82      8244
#    macro avg       0.82      0.82      0.82      8244
# weighted avg       0.82      0.82      0.82      8244
#
#
#
# Testing Score
#                precision    recall  f1-score   support
#
#            0       0.90      0.78      0.83      1033
#            1       0.55      0.76      0.64       372
#
#     accuracy                           0.77      1405
#    macro avg       0.73      0.77      0.74      1405
# weighted avg       0.81      0.77      0.78      1405

# %% [markdown]
# The final model demonstrates good generalization with a small gap between training (82%) and testing (77%) performance, indicating minimal overfitting. It successfully identifies 76% of actual churning customers while maintaining a Class 1 F1-score of 0.64. Although the model produces some false positives, this is an acceptable trade-off for churn prediction, where maximizing customer retention is the primary objective. Overall, the model is well-suited for supporting data-driven retention strategies in the IBM Telco Customer Churn dataset.

# %% [markdown]
# ## Find out the best threshold
#
# A typical workflow in production is:
#
# 1. Train the model.
# 2. Predict probabilities (predict_proba).
# 3. Evaluate the default threshold (0.5).
# 4. Plot the Precision-Recall curve and ROC curve.
# 5. Test multiple thresholds.
# 6. Select the threshold based on the business objective (e.g., maximize recall, maximize F1, or minimize expected business cost).
# 7. Retrain only if needed; otherwise, deploy the model with the chosen threshold.

# %% [markdown]
# #### Note:
# We will use the final best model's parameters and resampled data from now

# %%
best_params = best_clf.get_params()
best_params
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': 8,
#  'max_features': 'log2',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 15,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'monotonic_cst': None,
#  'n_estimators': 300,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': 42,
#  'verbose': 0,
#  'warm_start': False}

# %%
## Final data
# X_train_resampled
# y_train_resampled

# X_test, y_test

# %%
## Prediction the probabilites with the best model
y_prob = best_clf.predict_proba(X_test)[:, 1]
y_prob
# Out:
# array([0.43921661, 0.64420069, 0.1690443 , ..., 0.82008005, 0.27082079,
#        0.22831271], shape=(1405,))

# %%
## Draw the Precision-Recall Curve
from sklearn.metrics import precision_recall_curve
import matplotlib.pyplot as plt

precision, recall, thresholds = precision_recall_curve(
    y_test,
    y_prob
)

plt.figure(figsize=(8,6))

plt.plot(recall, precision, linewidth=2)

plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Precision-Recall Curve")

plt.grid(True)

plt.show()

# %%
## Compute the PR-AUC
# The area under the Precision-Recall Curve summarizes performance in a single value.
from sklearn.metrics import average_precision_score

pr_auc = average_precision_score(y_test, y_prob)
print("Average Precision (PR-AUC):", pr_auc)
# Out:
# Average Precision (PR-AUC): 0.6439685022729204

# %%
## Draw the ROC Curve
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score

fpr, tpr, thresholds = roc_curve(
    y_test,
    y_prob
)

roc_auc = roc_auc_score(
    y_test,
    y_prob
)

plt.figure(figsize=(8,6))

plt.plot(
    fpr,
    tpr,
    label=f"AUC = {roc_auc:.3f}",
    linewidth=2
)

plt.plot(
    [0,1],
    [0,1],
    linestyle="--",
    label="Random Classifier"
)

plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")

plt.title("ROC Curve")

plt.legend()

plt.grid(True)

plt.show()

# %%
print("ROC-AUC:", roc_auc)
# Out:
# ROC-AUC: 0.847003195619815

# %%
## Determine the Best Threshold Using Youden's J Statistic
# A common way to select a threshold from the ROC curve is to maximize TPR − FPR.

J = tpr - fpr
ix = np.argmax(J)

best_threshold = thresholds[ix]

print("Best Threshold:", best_threshold)
print("Sensitivity (TPR):", tpr[ix])
print("False Positive Rate:", fpr[ix])
# Out:
# Best Threshold: 0.44590287081154256
# Sensitivity (TPR): 0.8279569892473119
# False Positive Rate: 0.2671829622458858

# %%
## Final evaluation with thresold 0.41
threshold = 0.45
y_pred = (y_prob>=threshold).astype(int)

print(classification_report(y_true=y_test, y_pred=y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.74      0.82      1033
#            1       0.53      0.82      0.64       372
#
#     accuracy                           0.76      1405
#    macro avg       0.72      0.78      0.73      1405
# weighted avg       0.82      0.76      0.77      1405

# %%
clf_grid.best_estimator_.__class__.__name__
# Out:
# 'RandomForestClassifier'

# %% [markdown]
# ## Final Model Evaluation
#
# The customer churn prediction model was first evaluated using the default classification threshold of **0.50** and then re-evaluated after optimizing the threshold to **0.45**.
#
# ### Model Performance Comparison
#
# | Metric            | Threshold = 0.50 | Threshold = 0.45 |
# | ----------------- | ---------------: | ---------------: |
# | Accuracy          |         **0.77** |             0.76 |
# | Precision (Churn) |         **0.55** |             0.53 |
# | Recall (Churn)    |             0.76 |         **0.82** |
# | F1-score (Churn)  |             0.64 |             0.64 |
#
# <br/>
#
# ## Interpretation
#
# ### 1. Default Threshold (0.50)
#
# Using the default threshold of **0.50**, the model achieved:
#
# * **77% overall accuracy**
# * **55% precision** for churn prediction
# * **76% recall** for churn prediction
# * **F1-score of 0.64**
#
# This means that:
#
# * The model correctly identified **76% of customers who actually churned**.
# * About **24% of churning customers were missed**.
# * Among all customers predicted as churners, **55% actually churned**.
#
# This provides a balanced baseline model with reasonable precision and recall.
#
# <br/>
#
# ### 2. Optimized Threshold (0.45)
#
# After reducing the classification threshold to **0.45**, the model became more sensitive to identifying churning customers.
#
# The updated performance was:
#
# * **76% overall accuracy**
# * **53% precision**
# * **82% recall**
# * **F1-score remained 0.64**
#
# The lower threshold resulted in:
#
# * An increase in churn recall from **76% to 82%**.
# * A decrease in churn precision from **55% to 53%**.
# * A slight decrease in overall accuracy from **77% to 76%**.
#
# This indicates that the model predicts more customers as potential churners, thereby identifying more actual churners while also increasing the number of false positives.
#
# <br/>
#
# ## Business Interpretation
#
# The objective of customer churn prediction is to identify customers who are likely to leave so that the business can take preventive actions.
#
# Comparing the two thresholds:
#
# ### Threshold = 0.50
#
# * Detects **76%** of churning customers.
# * Misses **24%** of actual churners.
# * Produces fewer false alarms.
#
# ### Threshold = 0.41
#
# * Detects **82%** of churning customers.
# * Misses only **18%** of actual churners.
# * Produces more false alarms because precision decreases.
#
# For customer retention campaigns, missing a customer who is about to churn is often more costly than contacting a customer who would have stayed. Therefore, improving recall is usually more valuable than maximizing precision.
#
# <br/>
#
# # Why Accuracy Decreased
#
# The slight reduction in accuracy (77% → 76%) is expected after lowering the threshold.
#
# As the threshold decreases:
#
# * More customers are classified as churners.
# * True Positives increase.
# * False Positives also increase.
#
# Since churn datasets are imbalanced, **accuracy alone is not an appropriate metric** for model selection. Recall, Precision, F1-score, ROC-AUC, and PR-AUC provide a more meaningful assessment.
#
# <br/>
#
# Therefore, **the model with a threshold of 0.45 is selected as the final deployment model** because it better aligns with the business objective of maximizing customer retention.

# %% [markdown]
# ## Export the model

# %%
import joblib

class ChurnPredictor:

    def __init__(self, model, threshold):
        self.model = model
        self.threshold = threshold

    def predict(self, X):

        prob = self.model.predict_proba(X)[:,1]

        return (prob >= self.threshold).astype(int)

    def predict_proba(self, X):

        return self.model.predict_proba(X)
    

## Save the model
predictor = ChurnPredictor(best_clf, 0.45)

joblib.dump(predictor, "../artifacts/churn_predictor.pkl")
# Out:
# ['../artifacts/churn_predictor.pkl']

# %%
## Load the model
predictor = joblib.load("../artifacts/churn_predictor.pkl")
prediction = predictor.predict(X_test)
prediction[:5]
# Out:
# array([0, 1, 0, 0, 0])

# %%
# import joblib

# # Define the model metadata
# model_metadata = {
#     'model': best_clf,
#     'features': X_train.columns.tolist(),
#     'thresholds': {'Low': 0.3, 'High': 0.7}
# }

# # Export the model to a file
# joblib.dump(model_metadata, '../Artifacts/Model/telco_churn_final_model.pkl')

# print("Model exported successfully as 'telco_churn_final_model.pkl'")
# Out:
# Model exported successfully as 'telco_churn_final_model.pkl'

# %% [markdown]
# ### What Happens in Industry?
#
# In production systems, it's common to keep the threshold in a configuration file or model metadata rather than hard-coding it.
#
# For example:
#
# ```yaml
# model:
#     name: churn_model.pkl
#     threshold: 0.45
#     version: 1.0.0
# ```
#
# or
#
# ```json
# {
#     "model": "churn_model.pkl",
#     "threshold": 0.45,
#     "roc_auc": 0.84,
#     "created_at": "2026-07-22"
# }
# ```
#
# The inference service reads the model and the threshold together, ensuring predictions use the same operating point that was selected during evaluation.
